# %%
# !pip install tensorflow
import numpy as np
import collections
import math
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
#--------------------------
# 1. Paths and parameters
#--------------------------
data_dir = "/kaggle/input/datasets/shuvammaity40/plant-village-sp-mohanty/SP_Mohanty/Apple"
img_size = (224, 224)
batch_size = 32
seed = 42

#------------------------------------------------
# 2. Load full dataset as unbatched and shuffled
#------------------------------------------------
full_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    seed=seed,
    image_size=img_size,
    batch_size=None,
    shuffle=True
)

total_images = tf.data.experimental.cardinality(full_ds).numpy()
train_size = int(0.7 * total_images)
val_size = int(0.15 * total_images)

#----------------------------
# 3. Split the shuffled pool
#----------------------------
train_ds = full_ds.take(train_size).batch(batch_size)
remaining = full_ds.skip(train_size)
val_ds = remaining.take(val_size).batch(batch_size)
test_ds = remaining.skip(val_size).batch(batch_size)
# Out:
# Found 3171 files belonging to 4 classes.

# %%
# -------------------------------
# 4. Performance optimizations
# -------------------------------
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds   = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds  = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# -------------------------------
# 5. Sanity check
# -------------------------------
print("Train batches:", tf.data.experimental.cardinality(train_ds).numpy())
print("Val batches:", tf.data.experimental.cardinality(val_ds).numpy())
print("Test batches:", tf.data.experimental.cardinality(test_ds).numpy())
# Out:
# Train batches: 70
# Val batches: 15
# Test batches: 15

# %%
class_names=full_ds.class_names
class_names
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy']

# %%
# Extract one sample image per class
found_images = {}
class_names = full_ds.class_names

for image, label in full_ds:
    label_idx = label.numpy()
    if label_idx not in found_images:
        # Convert to uint8 for proper plt.imshow rendering
        found_images[label_idx] = image.numpy().astype("uint8")

    # Stop once we have an image for every class
    if len(found_images) == len(class_names):
        break

# Plotting : 2 images per row
num_classes = len(class_names)
cols = 2
rows = math.ceil(num_classes / cols)

plt.figure(figsize=(10, 5 * rows))

for i, (idx, img) in enumerate(sorted(found_images.items())):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(f"Class: {class_names[idx]}", fontsize=12)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
def get_class_distribution(dataset, class_names):
    """Counts the number of images per class in a batched tf.data.Dataset."""
    counts = collections.Counter()
    # Iterating through the batches
    for _, labels in dataset:
        # labels is a tensor of shape (batch_size,)
        counts.update(labels.numpy())

    # Map indices back to class names
    return {class_names[i]: counts[i] for i in range(len(class_names))}

# Calculate distributions for each set

train_dist = get_class_distribution(train_ds, class_names)
val_dist = get_class_distribution(val_ds, class_names)
test_dist = get_class_distribution(test_ds, class_names)

# Print the formatted results
print(f"{'Class Name':<30} | {'Train':<7} | {'Val':<7} | {'Test':<7}")
print("-" * 60)
for name in class_names:
    print(f"{name:<30} | {train_dist.get(name, 0):<7} | {val_dist.get(name, 0):<7} | {test_dist.get(name, 0):<7}")
# Out:
# Class Name                     | Train   | Val     | Test
# ------------------------------------------------------------
# Apple___Apple_scab             | 438     | 97      | 89
# Apple___Black_rot              | 439     | 96      | 103
# Apple___Cedar_apple_rust       | 195     | 42      | 41
# Apple___healthy                | 1147    | 240     | 244

# %%
# Total number of images in the training set
total_train_images = sum(train_dist.values())
num_classes = len(class_names)

# Formula: total / (num_classes * class_count)
class_weight = {}
for i, name in enumerate(class_names):
    count = train_dist.get(name, 1) # avoid division by zero
    weight = total_train_images / (num_classes * count)
    class_weight[i] = weight

print("Calculated Class Weights:")
for i, name in enumerate(class_names):
    print(f"{name}: {class_weight[i]:.2f}")
# Out:
# Calculated Class Weights:
# Apple___Apple_scab: 1.27
# Apple___Black_rot: 1.26
# Apple___Cedar_apple_rust: 2.84
# Apple___healthy: 0.48

# %%
normalization = layers.Rescaling(1./255)

# %%
data_augmentation = Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

# %%
model = Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    data_augmentation,
    normalization,

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,476 (42.61 MB)
#  Trainable params: 11,169,476 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint = ModelCheckpoint(
    "best_apple_cnn.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

early_stopping = EarlyStopping(
    monitor="val_accuracy",
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    class_weight=class_weight,  # <--- CRITICAL STEP
    callbacks=[early_stopping, checkpoint]
)
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4034 - loss: 1.4459
# Epoch 1: val_accuracy improved from -inf to 0.75789, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.4047 - loss: 1.4419 - val_accuracy: 0.7579 - val_loss: 0.6318
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6728 - loss: 0.7654
# Epoch 2: val_accuracy improved from 0.75789 to 0.78737, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.6732 - loss: 0.7647 - val_accuracy: 0.7874 - val_loss: 0.5580
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7118 - loss: 0.6443
# Epoch 3: val_accuracy did not improve from 0.78737
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7121 - loss: 0.6437 - val_accuracy: 0.6968 - val_loss: 0.7962
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7487 - loss: 0.5737
# Epoch 4: val_accuracy improved from 0.78737 to 0.87158, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7491 - loss: 0.5732 - val_accuracy: 0.8716 - val_loss: 0.3500
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8089 - loss: 0.4269
# Epoch 5: val_accuracy did not improve from 0.87158
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8085 - loss: 0.4279 - val_accuracy: 0.8105 - val_loss: 0.5459
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8019 - loss: 0.4467
# Epoch 6: val_accuracy did not improve from 0.87158
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8018 - loss: 0.4471 - val_accuracy: 0.7011 - val_loss: 0.7294
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8117 - loss: 0.3998
# Epoch 7: val_accuracy improved from 0.87158 to 0.87579, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.8121 - loss: 0.3990 - val_accuracy: 0.8758 - val_loss: 0.3540
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8479 - loss: 0.3629
# Epoch 8: val_accuracy improved from 0.87579 to 0.90316, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.8480 - loss: 0.3627 - val_accuracy: 0.9032 - val_loss: 0.2411
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8922 - loss: 0.2505
# Epoch 9: val_accuracy did not improve from 0.90316
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.8919 - loss: 0.2514 - val_accuracy: 0.7895 - val_loss: 0.5533
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8383 - loss: 0.3652
# Epoch 10: val_accuracy did not improve from 0.90316
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8387 - loss: 0.3642 - val_accuracy: 0.8505 - val_loss: 0.4898
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8817 - loss: 0.3062
# Epoch 11: val_accuracy improved from 0.90316 to 0.92632, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.8818 - loss: 0.3057 - val_accuracy: 0.9263 - val_loss: 0.2247
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9158 - loss: 0.2031
# Epoch 12: val_accuracy did not improve from 0.92632
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9157 - loss: 0.2034 - val_accuracy: 0.9011 - val_loss: 0.2143
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9239 - loss: 0.1777
# Epoch 13: val_accuracy did not improve from 0.92632
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9238 - loss: 0.1778 - val_accuracy: 0.8989 - val_loss: 0.2972
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8976 - loss: 0.2545
# Epoch 14: val_accuracy improved from 0.92632 to 0.95579, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.8978 - loss: 0.2539 - val_accuracy: 0.9558 - val_loss: 0.1834
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9169 - loss: 0.2224
# Epoch 15: val_accuracy did not improve from 0.95579
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9169 - loss: 0.2225 - val_accuracy: 0.9453 - val_loss: 0.1172
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9173 - loss: 0.2410
# Epoch 16: val_accuracy did not improve from 0.95579
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9171 - loss: 0.2416 - val_accuracy: 0.9284 - val_loss: 0.1833
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9087 - loss: 0.2046
# Epoch 17: val_accuracy did not improve from 0.95579
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9087 - loss: 0.2045 - val_accuracy: 0.9474 - val_loss: 0.1450
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9251 - loss: 0.1692
# Epoch 18: val_accuracy did not improve from 0.95579
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9251 - loss: 0.1694 - val_accuracy: 0.9558 - val_loss: 0.1139
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9384 - loss: 0.1397
# Epoch 19: val_accuracy improved from 0.95579 to 0.96000, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9383 - loss: 0.1400 - val_accuracy: 0.9600 - val_loss: 0.1274
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9270 - loss: 0.1732
# Epoch 20: val_accuracy did not improve from 0.96000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9270 - loss: 0.1731 - val_accuracy: 0.9495 - val_loss: 0.1360
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9342 - loss: 0.1507
# Epoch 21: val_accuracy improved from 0.96000 to 0.96632, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9342 - loss: 0.1507 - val_accuracy: 0.9663 - val_loss: 0.0904
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9351 - loss: 0.1212
# Epoch 22: val_accuracy did not improve from 0.96632
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9351 - loss: 0.1214 - val_accuracy: 0.9537 - val_loss: 0.1258
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9270 - loss: 0.1735
# Epoch 23: val_accuracy improved from 0.96632 to 0.96842, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9272 - loss: 0.1731 - val_accuracy: 0.9684 - val_loss: 0.1002
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9282 - loss: 0.1791
# Epoch 24: val_accuracy did not improve from 0.96842
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9281 - loss: 0.1793 - val_accuracy: 0.9347 - val_loss: 0.1609
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9456 - loss: 0.1267
# Epoch 25: val_accuracy did not improve from 0.96842
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9456 - loss: 0.1266 - val_accuracy: 0.9663 - val_loss: 0.0796
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9475 - loss: 0.1003
# Epoch 26: val_accuracy improved from 0.96842 to 0.97895, saving model to best_apple_cnn.keras
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9475 - loss: 0.1004 - val_accuracy: 0.9789 - val_loss: 0.0616
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9469 - loss: 0.1165
# Epoch 27: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9470 - loss: 0.1164 - val_accuracy: 0.9558 - val_loss: 0.1146
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9336 - loss: 0.1570
# Epoch 28: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9337 - loss: 0.1569 - val_accuracy: 0.9305 - val_loss: 0.1445
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9250 - loss: 0.1884
# Epoch 29: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9249 - loss: 0.1883 - val_accuracy: 0.9642 - val_loss: 0.1008
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9563 - loss: 0.1101
# Epoch 30: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9563 - loss: 0.1100 - val_accuracy: 0.9705 - val_loss: 0.0754
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9626 - loss: 0.0926
# Epoch 31: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9624 - loss: 0.0930 - val_accuracy: 0.9747 - val_loss: 0.0982
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9345 - loss: 0.1690
# Epoch 32: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9346 - loss: 0.1686 - val_accuracy: 0.9705 - val_loss: 0.0904
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9610 - loss: 0.0999
# Epoch 33: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9610 - loss: 0.1000 - val_accuracy: 0.9684 - val_loss: 0.0772
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9391 - loss: 0.1695
# Epoch 34: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9392 - loss: 0.1692 - val_accuracy: 0.9747 - val_loss: 0.0663
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9497 - loss: 0.0890
# Epoch 35: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9498 - loss: 0.0890 - val_accuracy: 0.9747 - val_loss: 0.0671
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9653 - loss: 0.1034
# Epoch 36: val_accuracy did not improve from 0.97895
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9653 - loss: 0.1033 - val_accuracy: 0.9558 - val_loss: 0.1135
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %%
# --- Plot training history ---
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
best_model = tf.keras.models.load_model("best_apple_cnn.keras")

# %%
# Calculate Training Metrics
train_loss, train_acc = best_model.evaluate(train_ds)
print(f"Train Accuracy: {train_acc*100:.2f}%")
print(f"Train Loss: {train_loss}%")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 22s 310ms/step - accuracy: 0.9803 - loss: 0.0506
# Train Accuracy: 98.06%
# Train Loss: 0.05332563817501068%

# %%
# Calculate Validation Metrics
val_loss, val_acc = best_model.evaluate(val_ds)
print(f"Val Accuracy: {val_acc*100:.2f}%")
print(f"Val Loss: {val_loss}%")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - accuracy: 0.9811 - loss: 0.0554
# Val Accuracy: 97.89%
# Val Loss: 0.06155654042959213%

# %%
# Calculate Test Metrics
test_loss, test_acc = best_model.evaluate(test_ds)
print(f"Test Accuracy: {test_acc*100:.2f}%")
print(f"Test Loss: {test_loss}%")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 312ms/step - accuracy: 0.9583 - loss: 0.0903
# Test Accuracy: 97.27%
# Test Loss: 0.06707985699176788%

# %%
# 1. Take one batch from the test set
for images, labels in test_ds.take(1):
    # 2. Generate predictions for the entire batch
    # This returns a 2D array of probabilities (one row per image)
    predictions = model.predict(images)

    plt.figure(figsize=(16, 12))

    # 3. Plot the first 9 images from this batch
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)

        # Display the image (handle uint8 conversion)
        plt.imshow(images[i].numpy().astype("uint8"))

        # Get the index of the highest probability
        pred_label_idx = np.argmax(predictions[i])
        actual_label_idx = labels[i].numpy()

        # Set color: Green if correct, Red if wrong
        color = 'green' if pred_label_idx == actual_label_idx else 'red'

        plt.title(
            f"Actual: {class_names[actual_label_idx]}\n"
            f"Predicted: {class_names[pred_label_idx]}",
            color=color, fontsize=10
        )
        plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step

# %%
# Extract true labels from the test_ds
print("Extracting true labels...")
y_true = np.concatenate([y for x, y in test_ds], axis=0)

# Get model predictions (probabilities)
print("Generating predictions...")
y_probs = model.predict(test_ds)

# Convert probabilities to class indices
y_pred = np.argmax(y_probs, axis=1)

# Generate and print the Classification Report
print("\n" + "="*20 + " CLASSIFICATION REPORT " + "="*20)
print(classification_report(y_true, y_pred, target_names=class_names, zero_division=0))
# Out:
# Extracting true labels...
# Generating predictions...
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step
#
# ==================== CLASSIFICATION REPORT ====================
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       0.95      0.92      0.94        89
#        Apple___Black_rot       0.99      0.99      0.99       103
# Apple___Cedar_apple_rust       1.00      1.00      1.00        41
#          Apple___healthy       0.97      0.98      0.97       244
#
#                 accuracy                           0.97       477
#                macro avg       0.98      0.97      0.98       477
#             weighted avg       0.97      0.97      0.97       477

# %%
# Plotting a Confusion Matrix for better visualization
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
